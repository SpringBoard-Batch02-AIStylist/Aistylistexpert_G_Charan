# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('D:/JN/myntradataset/aistylist.csv')

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44441  17036    Men       Footwear       Shoes           Casual Shoes
# 44442   6461    Men       Footwear  Flip Flops             Flip Flops
# 44443  18842    Men        Apparel     Topwear                Tshirts
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
df.drop('Unnamed: 10',axis=1,inplace=True)

# %%
df.drop('Unnamed: 11',axis=1,inplace=True)

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44441  17036    Men       Footwear       Shoes           Casual Shoes
# 44442   6461    Men       Footwear  Flip Flops             Flip Flops
# 44443  18842    Men        Apparel     Topwear                Tshirts
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
df.tail(10)
# Out:
#           id gender masterCategory subCategory            articleType  \
# 44436  30614    Men        Apparel     Topwear                Tshirts
# 44437  13496    Men        Apparel     Topwear                Tshirts
# 44438  55283  Women  Personal Care      Makeup  Highlighter and Blush
# 44439  12544  Women        Apparel     Topwear                Tshirts
# 44440  42234  Women        Apparel     Topwear                   Tops
# 44441  17036    Men       Footwear       Shoes           Casual Shoes
# 44442   6461    Men       Footwear  Flip Flops             Flip Flops
# 44443  18842    Men        Apparel     Topwear                Tshirts
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 44436      Black  Summer  2012.0  Sports
# 44437       Blue    Fall  2011.0  Casual
# 44438       Pink  Spring  2017.0  Casual
# ...

# %%
#sanity check of data
df.shape
# Out:
# (44446, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44446 non-null  int64
#  1   gender              44446 non-null  object
#  2   masterCategory      44446 non-null  object
#  3   subCategory         44446 non-null  object
#  4   articleType         44446 non-null  object
#  5   baseColour          44431 non-null  object
#  6   season              44425 non-null  object
#  7   year                44445 non-null  float64
#  8   usage               44129 non-null  object
#  9   productDisplayName  44439 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.4+ MB

# %%
#finding issing values

df.isnull().sum()
# Out:
# id                      0
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# year                    1
# usage                 317
# productDisplayName      7
# dtype: int64

# %%
#gives the percentage of missing value

df.isnull().sum()/df.shape[0]*100
# Out:
# id                    0.000000
# gender                0.000000
# masterCategory        0.000000
# subCategory           0.000000
# articleType           0.000000
# baseColour            0.033749
# season                0.047248
# year                  0.002250
# usage                 0.713225
# productDisplayName    0.015749
# dtype: float64

# %%
# finding the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
#identifying the garbage values


for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("****" *10)
# Out:
# gender
# Men       22165
# Women     18632
# Unisex     2164
# Boys        830
# Girls       655
# Name: count, dtype: int64
# ****************************************
# masterCategory
# Apparel           21400
# Accessories       11289
# Footwear           9222
# Personal Care      2404
# Free Items          105
# Sporting Goods       25
# Home                  1
# Name: count, dtype: int64
# ****************************************
# subCategory
# Topwear                     15405
# Shoes                        7344
# Bags                         3055
# Bottomwear                   2694
# Watches                      2542
# Innerwear                    1808
# Jewellery                    1080
# Eyewear                      1073
# Fragrance                    1012
# Sandal                        963
# Wallets                       933
# Flip Flops                    915
# Belts                         811
# Socks                         698
# Lips                          527
# ...

# %%
#EDA

df.describe()
# Out:
#                  id          year
# count  44446.000000  44445.000000
# mean   29692.631350   2012.805940
# std    17048.234982      2.126401
# min     1163.000000   2007.000000
# 25%    14770.250000   2011.000000
# 50%    28609.500000   2012.000000
# 75%    44678.750000   2015.000000
# max    60000.000000   2019.000000

# %%
df.describe(include="object")
# Out:
#        gender masterCategory subCategory articleType baseColour  season  \
# count   44446          44446       44446       44446      44431   44425
# unique      5              7          45         143         46       4
# top       Men        Apparel     Topwear     Tshirts      Black  Summer
# freq    22165          21400       15405        7070       9732   21476
#
#          usage            productDisplayName
# count    44129                         44439
# unique       8                         31135
# top     Casual  Lucera Women Silver Earrings
# freq     34414                            82

# %%
#histogram
import seaborn as sns
import matplotlib.pyplot as plt
for i in df.select_dtypes(include="object").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
df.select_dtypes(include="object").columns

# %%
import pandas as pd
import os
df = pd.read_csv('D:/JN/myntradataset/aistylist.csv')

# %%
df

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df.select_dtypes(include="object").columns

# %%
df.drop('Unnamed: 10',axis=1,inplace=True)

# %%
df.drop('Unnamed: 11',axis=1,inplace=True)

# %%
df.select_dtypes(include="object").columns

# %%
for i in [ 'masterCategory', 'subCategory', 'articleType', 'baseColour',
       'season', 'usage', 'productDisplayName']:
    sns.scatterplot(data=df,x=i,y='gender')
    plt.show()

# %%
#correlation between data


df.select_dtypes(include="object").corr()

# %%
sns.heatmap(s)

# %%
import pandas as pd
import os
df = pd.read_csv('D:/JN/myntradataset/aistylist.csv')

# %%
df.drop('Unnamed: 11',axis=1,inplace=True)

# %%
df.drop('Unnamed: 10',axis=1,inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df.select_dtypes(include="object").columns

# %%
for i in [ 'masterCategory', 'subCategory', 'articleType', 'baseColour',
       'season', 'usage', 'productDisplayName']:
    sns.scatterplot(data=df,x=i,y='gender')
    plt.show()

# %%
s=df.select_dtypes(include="number").corr()

# %%
sns.heatmap(s)

# %%
df

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('D:/infoysys_dataset/aistylist.csv')

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44441  17036    Men       Footwear       Shoes           Casual Shoes
# 44442   6461    Men       Footwear  Flip Flops             Flip Flops
# 44443  18842    Men        Apparel     Topwear                Tshirts
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
df.drop('Unnamed: 10',axis=1,inplace=True)

# %%
df.drop('Unnamed: 11',axis=1,inplace=True)

# %%
df

# %%
df.shape
# Out:
# (44446, 10)

# %%
df.dtypes

# %%
df.isnull().sum()
# Out:
# id                      0
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# year                    1
# usage                 317
# productDisplayName      7
# dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
#
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
#dealing with missing values
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
x=df[['baseColour','season','year','usage','productDisplayName']].values

# %%
x

# %%
#filling missing values
object_columns = df.select_dtypes(include=['object']).columns

# %%
print("\nMissing values in object columns before processing:")
print(df[object_columns].isnull().sum())
# Out:
# Missing values in object columns before processing:
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# usage                 317
# productDisplayName      7
# dtype: int64

# %%
for col in object_columns:
    most_frequent = df[col].mode()[0]
    df[col].fillna(most_frequent, inplace=True)
# Out:
# C:\Users\CSC\AppData\Local\Temp\ipykernel_9088\2863083516.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(most_frequent, inplace=True)

# %%
print("\nMissing values in object columns after processing:")
print(df[object_columns].isnull().sum())
# Out:
# Missing values in object columns after processing:
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
print("\nCleaned DataFrame:")
print(df.info())
# Out:
# Cleaned DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44446 non-null  int64
#  1   gender              44446 non-null  object
#  2   masterCategory      44446 non-null  object
#  3   subCategory         44446 non-null  object
#  4   articleType         44446 non-null  object
#  5   baseColour          44446 non-null  object
#  6   season              44446 non-null  object
#  7   year                44445 non-null  float64
#  8   usage               44446 non-null  object
#  9   productDisplayName  44446 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.4+ MB
# None

# %%
df.isnull().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  1
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
if 'year' in df.columns:
    most_frequent_year = df['year'].mode()[0]
    df['year'].fillna(most_frequent_year, inplace=True)
# Out:
# C:\Users\CSC\AppData\Local\Temp\ipykernel_9088\1617799.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['year'].fillna(most_frequent_year, inplace=True)

# %%
print(df[object_columns].isnull().sum())
# Out:
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  0
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
#now all columns are removed with missing values and has zero missing values

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44441  17036    Men       Footwear       Shoes           Casual Shoes
# 44442   6461    Men       Footwear  Flip Flops             Flip Flops
# 44443  18842    Men        Apparel     Topwear                Tshirts
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  0
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
df.to_csv('preprocessed_dataset.csv', index=False)

# %%
import pandas as pd

# Load the preprocessed dataset
df = pd.read_csv('preprocessed_dataset.csv')

# Display the loaded DataFrame
print("Loaded Preprocessed DataFrame:")
print(df.info())
# Out:
# Loaded Preprocessed DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44446 entries, 0 to 44445
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  44446 non-null  int64
#  1   gender              44446 non-null  object
#  2   masterCategory      44446 non-null  object
#  3   subCategory         44446 non-null  object
#  4   articleType         44446 non-null  object
#  5   baseColour          44446 non-null  object
#  6   season              44446 non-null  object
#  7   year                44446 non-null  float64
#  8   usage               44446 non-null  object
#  9   productDisplayName  44446 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.4+ MB
# None
